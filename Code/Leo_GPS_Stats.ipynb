# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd

# %%
Dist_942 = pd.read_csv('../Analysis/Basic_Stats/2022/Dis_Aum_942.csv')
Dist_943 = pd.read_csv('../Analysis/Basic_Stats/2022/Dis_Aum_943.csv')
Dist_947 = pd.read_csv('../Analysis/Basic_Stats/2022/Dis_Aum_947.csv')
Dist_939 = pd.read_csv('../Analysis/Basic_Stats/2022/Dis_Aum_939.csv')
Dist_1101 = pd.read_csv('../Analysis/Basic_Stats/2022/Dis_Aum_1101.csv')
Dist_942_23 = pd.read_csv('../Analysis/Basic_Stats/2023/Dis_Aum_942.csv')
Dist_947_23 = pd.read_csv('../Analysis/Basic_Stats/2023/Dis_Aum_947.csv')
Dist_942.head()
# Out:
#    OBJECTID  IN_FID  NEAR_FID    NEAR_DIST
# 0         0       0       566  4061.842404
# 1         0       1       566  4059.975632
# 2         0       2       566  4116.180294
# 3         0       3       566  4042.406225
# 4         0       4       566  4023.491156

# %%
print (Dist_942.shape, Dist_939.shape,Dist_943.shape)
print (Dist_947.shape)
print (Dist_1101.shape)
print (Dist_942_23.shape, Dist_947_23.shape)
# Out:
# (23865, 4) (23777, 4) (23314, 4)
# (9320, 4)
# (18500, 4)
# (2915, 4) (2866, 4)

# %%
Flock4 = []
tmp_flock = Dist_942_23[(Dist_942_23['NEAR_DIST']<7200) & (Dist_942_23['NEAR_DIST']>5000)]
Flock4.append(tmp_flock['NEAR_DIST'].values)
tmp_flock = Dist_947_23[(Dist_947_23['NEAR_DIST']<7200) & (Dist_942_23['NEAR_DIST']>5000)]
Flock4.append(tmp_flock['NEAR_DIST'].values)
Flock4 = np.concatenate(Flock4)
Flock4 /= 1600



# plt.hist(Flock1,bins = 50, label = 'Flock 1, median value = ' + str(round(np.percentile(Flock1,50),2)) + 'mile', density = True)
# plt.hist(Flock2,bins = 50, label = 'Flock 2, median value = ' + str(round(np.percentile(Flock2,50),2)) + 'mile', density = True)
# plt.hist(Flock3,bins = 50, label = 'Flock 3, median value = ' + str(round(np.percentile(Flock3,50),2)) + 'mile', density = True)
plt.hist(Flock4,bins = 30, label = 'Flock 4, median value = ' + str(round(np.percentile(Flock4,50),2)) + 'mile', density = True)


plt.title('Distance to AUMs in 2023 Flocks')
yticks = plt.gca().get_yticks()
plt.yticks(yticks, np.round(yticks/70 , 2))
plt.legend()
plt.xlabel('Distance (mile)')
plt.ylabel('Frequency')
# Out:
# C:\Users\DawnMoon\AppData\Local\Temp\ipykernel_40420\3322430791.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tmp_flock = Dist_947_23[(Dist_947_23['NEAR_DIST']<7200) & (Dist_942_23['NEAR_DIST']>5000)]
# Text(0, 0.5, 'Frequency')

# %%
fig,ax = plt.subplots(figsize = (10,3))
Flock1 = []
tmp_flock = Dist_942[Dist_942['NEAR_DIST']<5000]
Flock1.append(tmp_flock['NEAR_DIST'].values)
tmp_flock = Dist_943[Dist_943['NEAR_DIST']<5000]
Flock1.append(tmp_flock['NEAR_DIST'].values)
tmp_flock = Dist_939[Dist_939['NEAR_DIST']<5000]
Flock1.append(tmp_flock['NEAR_DIST'].values)
Flock1 = np.concatenate(Flock1)
Flock1 /= 1600

Flock2 = []
tmp_flock = Dist_947[Dist_947['NEAR_DIST']<5000]
Flock2.append(tmp_flock['NEAR_DIST'].values)
Flock2 = np.concatenate(Flock2)
Flock2 /= 1600

Flock3 = []
tmp_flock = Dist_1101[Dist_1101['NEAR_DIST']<5000]
Flock3.append(tmp_flock['NEAR_DIST'].values)
Flock3 = np.concatenate(Flock3)
Flock3 /= 1600

Flock4 = []
tmp_flock = Dist_942_23[(Dist_942_23['NEAR_DIST']<7200) & (Dist_942_23['NEAR_DIST']>5000)]
Flock4.append(tmp_flock['NEAR_DIST'].values)
tmp_flock = Dist_947_23[(Dist_947_23['NEAR_DIST']<7200) & (Dist_942_23['NEAR_DIST']>5000)]
Flock4.append(tmp_flock['NEAR_DIST'].values)
Flock4 = np.concatenate(Flock4)
Flock4 /= 1600



plt.hist(Flock1,bins = 50, label = 'Flock 1, median value = ' + str(round(np.percentile(Flock1,50),2)) + 'mile', density = True)
plt.hist(Flock2,bins = 50, label = 'Flock 2, median value = ' + str(round(np.percentile(Flock2,50),2)) + 'mile', density = True)
plt.hist(Flock3,bins = 50, label = 'Flock 3, median value = ' + str(round(np.percentile(Flock3,50),2)) + 'mile', density = True)
plt.hist(Flock4,bins = 10, label = 'Flock 4, median value = ' + str(round(np.percentile(Flock4,50),2)) + 'mile', density = True)


plt.title('Distance to AUMs in 2022, 2023 Flocks')
yticks = plt.gca().get_yticks()
plt.yticks(yticks, np.round(yticks/30 , 2))
plt.legend()
plt.xlabel('Distance (mile)')
plt.ylabel('Frequency')
# Out:
# C:\Users\DawnMoon\AppData\Local\Temp\ipykernel_40420\1660106011.py:27: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tmp_flock = Dist_947_23[(Dist_947_23['NEAR_DIST']<7200) & (Dist_942_23['NEAR_DIST']>5000)]
# Text(0, 0.5, 'Frequency')

# %%
flock_942 = Dist_942_23[(Dist_942_23['NEAR_DIST']<7200) & (Dist_942_23['NEAR_DIST']>5000)]['NEAR_DIST']
flock_947 = Dist_947_23[(Dist_947_23['NEAR_DIST']<7200) & (Dist_942_23['NEAR_DIST']>5000)]['NEAR_DIST']
flock_942 /= 1600
flock_947 /= 1600



# plt.hist(Flock1,bins = 50, label = 'Flock 1, median value = ' + str(round(np.percentile(Flock1,50),2)) + 'mile', density = True)
# plt.hist(Flock2,bins = 50, label = 'Flock 2, median value = ' + str(round(np.percentile(Flock2,50),2)) + 'mile', density = True)
# plt.hist(Flock3,bins = 50, label = 'Flock 3, median value = ' + str(round(np.percentile(Flock3,50),2)) + 'mile', density = True)
plt.hist(flock_947,bins = 20, label = '947, median value = ' + str(round(np.percentile(flock_947,50),2)) + 'mile', density = True, alpha = 0.5)
plt.hist(flock_942,bins = 5, label = '942, median value = ' + str(round(np.percentile(flock_942,50),2)) + 'mile', density = True, alpha = 0.5)

plt.title('Distance to AUMs in 2023 Flocks, per individual')
yticks = plt.gca().get_yticks()
plt.yticks(yticks, np.round(yticks/60 , 2))
plt.legend()
plt.xlabel('Distance (mile)')
plt.ylabel('Frequency')
# Out:
# C:\Users\DawnMoon\AppData\Local\Temp\ipykernel_40420\3943925925.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   flock_947 = Dist_947_23[(Dist_947_23['NEAR_DIST']<7200) & (Dist_942_23['NEAR_DIST']>5000)]['NEAR_DIST']
# Text(0, 0.5, 'Frequency')

# %%
np.mean(Flock2)
np.median(Flock2)
# Out:
# 1272.7152278653384

# %%
speed = df_939['speed']
speed = np.sort(speed)
alpha = 0.1
speed = speed[int(speed.shape[0]*alpha):int(speed.shape[0]*(1-alpha))]
plt.hist(speed)
plt.xlim(0,20)
speed[0], speed[-1]
# Out:
# (0.19705118559057702, 2.9181122631977896)

# %%
dis = df_939['distance']
dis = np.sort(dis)
alpha = 0.1
dis = dis[int(dis.shape[0]*alpha):int(dis.shape[0]*(1-alpha))]
plt.hist(dis)
#plt.xlim(0,20)
dis[0], dis[-1]
# Out:
# (2.03571942814069, 35.02119788011925)

# %%
ODBA_mean = df_939['ODBA_mean']
ODBA_mean = np.sort(ODBA_mean)
alpha = 0.1
ODBA_mean = ODBA_mean[int(ODBA_mean.shape[0]*alpha):int(ODBA_mean.shape[0]*(1-alpha))]
plt.hist(ODBA_mean)
#plt.xlim(0,20)
ODBA_mean[0], ODBA_mean[-1]
# Out:
# (36.949748743718594, 49.28140703517589)

# %%
ODBA_std = df_939['ODBA_std']
ODBA_std = np.sort(ODBA_std)
alpha = 0.1
ODBA_std = ODBA_std[int(ODBA_std.shape[0]*alpha):int(ODBA_std.shape[0]*(1-alpha))]
plt.hist(ODBA_std)
#plt.xlim(0,20)
ODBA_std[0], ODBA_std[-1]
# Out:
# (0.9383135469102779, 10.794022193720643)

# %%
speed_low, speed_high = 0.19705118559057702, 2.9181122631977896
ODBA_low, ODBA_high = 
#df_939['']

# %%
ODBA_std = df_939['ODBA_std']
ODBA_std = np.sort(ODBA_std)
alpha = 0.4
ODBA_std = ODBA_std[int(ODBA_std.shape[0]*alpha):int(ODBA_std.shape[0]*(1-alpha))]
plt.hist(ODBA_std)
#plt.xlim(0,20)
ODBA_std[0], ODBA_std[-1]
# Out:
# (3.0097775901875865, 4.372558137410378)
